# %%
import sys
sys.path.append('..')

# %%
from modules.vizhelpercode import viewArbitraryVolume

# %%
from modules.mischelpers import open_hdf5

# %%
hf = open_hdf5()

# %%
viewArbitraryVolume(hf['training_data_hgg'][0], slice_idx=3)

# %%
import nilearn as nl
